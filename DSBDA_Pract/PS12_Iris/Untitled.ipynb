# %% [markdown]
# # Problem Statement No. 12

# %% [markdown]
# ## Scan the Iris dataset and give the inference as:
# ### 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# ### 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# ### 3. Create a boxplot for each feature in the dataset.
# ### 4. Compare distributions and identify outliers

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.histplot(df, x = 'SepalLengthCm', hue = 'Species')
plt.show()

# %%
sns.histplot(df,x = 'SepalLengthCm')
plt.show()

# %%
sns.histplot(df,x = 'SepalWidthCm')
plt.show()

# %%
sns.histplot(df,x = 'PetalLengthCm')
plt.show()

# %%
sns.histplot(df,x = 'PetalWidthCm')
plt.show()

# %%
sns.boxplot(df, x = 'SepalLengthCm')
plt.show()

# %%
sns.boxplot(df, x = 'SepalWidthCm')
plt.show()

# %%
sns.boxplot(df, x = 'PetalLengthCm')
plt.show()

# %%
sns.boxplot(df, x = 'PetalWidthCm')
plt.show()

# %%
df.drop('Id', axis = 1, inplace = True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >
